# %%
# Arquivo de sincronização entre git e github para testes de versionamento e sincronização

# Arquivo: git_github_poc.ipynb

# Sinconização: v01

# %%
# Arquivo de sincronização entre git e github para testes de versionamento e sincronização

# Arquivo: git_github_poc.ipynb

# Sinconização: v02

# Origem: 
    # Equipamento B (Fedora)
    # Conta github (fabiofumio)
